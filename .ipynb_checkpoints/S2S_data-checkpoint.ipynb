# %%
import xarray as xr
from netCDF4 import Dataset, num2date

# %%
data = xr.open_dataset("S2S_Data/precip_refcst_control.nc")
ds=Dataset("S2S_Data/precip_refcst_control.nc")

# %%
data
# Out:
# <xarray.Dataset>
# Dimensions:     (step: 185, latitude: 121, longitude: 240)
# Coordinates:
#     number      int64 ...
#     time        datetime64[ns] ...
#   * step        (step) timedelta64[ns] 0 days 00:00:00 ... 46 days 00:00:00
#     surface     float64 ...
#   * latitude    (latitude) float64 90.0 88.5 87.0 85.5 ... -87.0 -88.5 -90.0
#   * longitude   (longitude) float64 0.0 1.5 3.0 4.5 ... 354.0 355.5 357.0 358.5
#     valid_time  (step) datetime64[ns] ...
# Data variables:
#     tp          (step, latitude, longitude) float32 ...
# Attributes:
#     GRIB_edition:            2
#     GRIB_centre:             ecmf
#     GRIB_centreDescription:  European Centre for Medium-Range Weather Forecasts
#     GRIB_subCentre:          0
#     Conventions:             CF-1.7
#     institution:             European Centre for Medium-Range Weather Forecasts
#     history:                 2024-12-03T11:14 GRIB to CDM+CF via cfgrib-0.9.1...

# %%
pwd
#filepath=/projects/aija9929/Final_Project_ATOC4500_F24/S2S_Data/precip_refcst_control.nc'
# Out:
# '/projects/aija9929/Final_Project_ATOC4500_F24'

# %%
ds
# Out:
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF4 data model, file format HDF5):
#     GRIB_edition: 2
#     GRIB_centre: ecmf
#     GRIB_centreDescription: European Centre for Medium-Range Weather Forecasts
#     GRIB_subCentre: 0
#     Conventions: CF-1.7
#     institution: European Centre for Medium-Range Weather Forecasts
#     history: 2024-12-03T11:14 GRIB to CDM+CF via cfgrib-0.9.14.1/ecCodes-2.39.0 with {"source": "S2S_Data/precip_refcst_control.grib", "filter_by_keys": {}, "encode_cf": ["parameter", "time", "geography", "vertical"]}
#     dimensions(sizes): step(185), latitude(121), longitude(240)
#     variables(dimensions): int64 number(), int64 time(), float64 step(step), float64 surface(), float64 latitude(latitude), float64 longitude(longitude), float64 valid_time(step), float32 tp(step, latitude, longitude)
#     groups:

# %%
step_array=ds.variables['step']
print(step_array)
step_array=ds.variables['step'][:]
print(step_array)
# Out:
# <class 'netCDF4._netCDF4.Variable'>
# float64 step(step)
#     _FillValue: nan
#     long_name: time since forecast_reference_time
#     standard_name: forecast_period
#     units: hours
# unlimited dimensions:
# current shape = (185,)
# filling on
# [   0.    6.   12.   18.   24.   30.   36.   42.   48.   54.   60.   66.
#    72.   78.   84.   90.   96.  102.  108.  114.  120.  126.  132.  138.
#   144.  150.  156.  162.  168.  174.  180.  186.  192.  198.  204.  210.
#   216.  222.  228.  234.  240.  246.  252.  258.  264.  270.  276.  282.
#   288.  294.  300.  306.  312.  318.  324.  330.  336.  342.  348.  354.
#   360.  366.  372.  378.  384.  390.  396.  402.  408.  414.  420.  426.
#   432.  438.  444.  450.  456.  462.  468.  474.  480.  486.  492.  498.
#   504.  510.  516.  522.  528.  534.  540.  546.  552.  558.  564.  570.
#   576.  582.  588.  594.  600.  606.  612.  618.  624.  630.  636.  642.
# ...

# %%
#da.sel(lat=50.5, lon=50.5).plot()
data.tp.sel(step='3974400000000000').plot()

# %%
data.tp.sel(step='3974400000000000',latitude=slice('19.5', '60')).plot()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [24], in <cell line: 1>()
# ----> 1 data.tp.sel(step='3974400000000000',latitude=slice(19.5, 60)).plot()
#
# File /curc/sw/anaconda3/2022.10/envs/ATOC_NWP/lib/python3.10/site-packages/xarray/plot/plot.py:868, in _PlotMethods.__call__(self, **kwargs)
#     867 def __call__(self, **kwargs):
# --> 868     return plot(self._da, **kwargs)
#
# File /curc/sw/anaconda3/2022.10/envs/ATOC_NWP/lib/python3.10/site-packages/xarray/plot/plot.py:334, in plot(darray, row, col, col_wrap, ax, hue, rtol, subplot_kws, **kwargs)
#     330     plotfunc = hist
#     332 kwargs["ax"] = ax
# --> 334 return plotfunc(darray, **kwargs)
#
# ...
